# %% [markdown]
# # GP2 Pathogenic Variant Analysis
#
# - **Project:** Parkinson’s Disease Pathogenic Variants: Cross-Ancestry Analysis and Microarray Data Validation
# - **Version:** Python/3.10.15
#
# ## Notebook Overview
#
# - Annotating variants across all ancestries utilizing ANNOVAR's ClinVar database for "Pathogenic" variants in established Parkinson's Disease genes (as defined by Blauwendraat et al. 2019)
#
# ## CHANGELOG
#
# - 14-NOV-2024: Notebook started
#
# ---

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Importing Packages

# %%
import os
import pandas as pd
import numpy as np
import sys as sys

from datetime import date
today = date.today()
date = today.strftime("%d-%b-%Y").upper()

# print out packages and versions
print(f'PACKAGE VERSION ({date})')
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# PACKAGE VERSION (18-NOV-2024)
# pandas==2.2.3
# numpy==1.25.2

# %% [markdown]
# # Run Analysis
#
# - GP2 release 7 (all ancestries)

# %%
# define paths/variables

wd = '' # working directory
gp2_tier2 = '' # path to GP2 tier 2 data

plink_exec = '' # path to plink executable
plink2_exec = '' # path to plink2.0 executable

ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAH', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS']

# %%
# utility function

def shell_do(command):
    print(f'Executing: {command}', file=sys.stderr)
    # !$command

# %% [markdown]
# ## convert gp2 release 7 pfiles to bfiles

# %%
# convert the gp2 release 7 pfiles to bfiles for each chromosome of interest for each ancestry group

# list of all ancestries
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAH', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS']

# list of chromosomes that contain a PD gene of interest
chrom_list = ['1','2','3','4','6','12','14','15','16','17','19','20','21','22']

for anc in ancestries:
    gp2_anc_path = f'{gp2_tier2}/imputed_genotypes/{anc}'
    gp2_anc_samples = f'{gp2_tier2}/raw_genotypes/{anc}/{anc}_release7_vwb.samples'
    print(f'WORKING ON {anc}')
    for chrom in chrom_list:
        plink_cmd = f'{plink2_exec} --pfile {gp2_anc_path}/chr{chrom}_{anc}_release7_vwb \
                      --keep {gp2_anc_samples} \
                      --make-bed --out {workspace}/bfiles/{anc}_{chrom}'
        shell_do(plink_cmd);
    print(f'COMPLETED {anc}')
    print('----------------------------------------')

# %%
# create merge files for each ancestry

for anc in ancestries:
    with open(f'{workspace}/bfiles/merge_files_{anc}.txt', 'w') as f:
        for chrom in chrom_list:
            f.write(f'{workspace}/bfiles/{anc}_{chrom}\n')
    f.close()

# %%
# merge chromosomes together for each ancestry

for anc in ancestries:
    plink_merge = f'{plink_exec} --merge-list {workspace}/bfiles/merge_files_{anc}.txt \
                    --make-bed --out {workspace}/bfiles/MERGE_{anc}'

    shell_do(plink_merge);
    print(f'{anc} MERGE COMPLETED')

# %%
# check that all ancestries were merged

# !ls {workspace}/bfiles/MERGE*

# %% [raw]
# to prep files for ANNOVAR annotations:
#
# note: check that fid and iid in .fam files are the same
# note: check that variant IDs have a leading "chr" in .bim files
# note: check that .bim files have no header

# %% [markdown]
# ## annotate the .bim files

# %%
# %cd {workspace}/bfiles
# Out:
# /home/jupyter/workspace/bfiles

# %%
# !cat MERGE_AAC.bim MERGE_AFR.bim MERGE_AJ.bim MERGE_AMR.bim MERGE_CAH.bim MERGE_CAS.bim MERGE_EAS.bim MERGE_EUR.bim MERGE_FIN.bim MERGE_MDE.bim MERGE_SAS.bim | awk '{print $2}' | sort | uniq > all_ancestries.txt

# %%
# %%bash
#
# # input and output file names
# input_file="all_ancestries.txt"
# output_file="to_annotate.txt"
#
# # create an empty output file
# > "$output_file"
#
# # process each line of the input file
# while IFS=$':' read -r chr pos ref alt; do
#     # write the formatted line to the output file
#     echo "$chr $pos $pos $ref $alt" >> "$output_file"
# done < "$input_file"
#
# echo "Processing complete. Output saved to $output_file"
# Out:
# Processing complete. Output saved to to_annotate.txt

# %% [markdown]
# ### download annovar libraries

# %%
# !/home/jupyter/annovar/annotate_variation.pl -buildver hg38 -downdb -webfrom annovar refGene /home/jupyter/annovar/humandb/
# !/home/jupyter/annovar/annotate_variation.pl -buildver hg38 -downdb -webfrom annovar avsnp151 /home/jupyter/annovar/humandb/
# !/home/jupyter/annovar/annotate_variation.pl -buildver hg38 -downdb -webfrom annovar clinvar_20240917 /home/jupyter/annovar/humandb/
# !/home/jupyter/annovar/annotate_variation.pl -buildver hg38 -downdb -webfrom annovar dbnsfp33a /home/jupyter/annovar/humandb/
# Out:
# NOTICE: Web-based checking to see whether ANNOVAR new version is available ... Done
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_refGene.txt.gz ... OK
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_refGeneMrna.fa.gz ... OK
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_refGeneVersion.txt.gz ... OK
# NOTICE: Uncompressing downloaded files
# NOTICE: Finished downloading annotation files for hg38 build version, with files saved at the '/home/jupyter/annovar/humandb' directory
# NOTICE: Web-based checking to see whether ANNOVAR new version is available ... Done
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_avsnp151.txt.gz ... OK
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_avsnp151.txt.idx.gz ... OK
# NOTICE: Uncompressing downloaded files
# NOTICE: Finished downloading annotation files for hg38 build version, with files saved at the '/home/jupyter/annovar/humandb' directory
# NOTICE: Web-based checking to see whether ANNOVAR new version is available ... Done
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_clinvar_20240917.txt.gz ... OK
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_clinvar_20240917.txt.idx.gz ... OK
# NOTICE: Uncompressing downloaded files
# NOTICE: Finished downloading annotation files for hg38 build version, with files saved at the '/home/jupyter/annovar/humandb' directory
# NOTICE: Web-based checking to see whether ANNOVAR new version is available ... Done
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_dbnsfp33a.txt.gz ... OK
# NOTICE: Downloading annotation database http://www.openbioinformatics.org/annovar/download/hg38_dbnsfp33a.txt.idx.gz ... OK
# NOTICE: Uncompressing downloaded files
# NOTICE: Finished downloading annotation files for hg38 build version, with files saved at the '/home/jupyter/annovar/humandb' directory

# %% [markdown]
# ### run annovar annotations

# %%
# command to run with just clinvar annotations (no CAD scores)

# !/home/jupyter/annovar/table_annovar.pl to_annotate.txt /home/jupyter/annovar/humandb/ -buildver hg38 -out all_ancestries_annotated -protocol refGene,avsnp151,clinvar_20240917 -operation g,f,f -nastring .
# Out:
# NOTICE: the --polish argument is set ON automatically (use --nopolish to change this behavior)
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile all_ancestries_annotated.refGene -exonsort -nofirstcodondel to_annotate.txt /home/jupyter/annovar/humandb/>
# NOTICE: Output files are written to all_ancestries_annotated.refGene.variant_function, all_ancestries_annotated.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1316 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1535 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1364 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1319 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1428 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1636 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 2175 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 2701 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 3385 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1706 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1608 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1168 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1459 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1654 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 992 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1162 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1292 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1070 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1258 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1029 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1318 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 800 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 627 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 890 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 896 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 5000000 unique variants in 5000000 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Finished analyzing 4000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 1547 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 3893589 unique variants in 3893589 input lines
# NOTICE: Finished analyzing 1000000 query variants
# NOTICE: Finished analyzing 2000000 query variants
# NOTICE: Finished analyzing 3000000 query variants
# NOTICE: Reading FASTA sequences from /home/jupyter/annovar/humandb/hg38_refGeneMrna.fa ... Done with 606 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Variants with invalid input format are written to all_ancestries_annotated.refGene.invalid_input
#
# NOTICE: Running with system command <coding_change.pl  all_ancestries_annotated.refGene.exonic_variant_function.orig /home/jupyter/annovar/humandb//hg38_refGene.txt /home/jupyter/annovar/humandb//hg38_refGeneMrna.fa -alltranscript -out all_ancestries_annotated.refGene.fa -newevf all_ancestries_annotated.refGene.exonic_variant_function>
# WARNING: cannot find annotation for NM_024616 in the genefile /home/jupyter/annovar/humandb//hg38_refGene.txt or cannot infer the transcription start site
# WARNING: cannot find annotation for NM_024616 in the genefile /home/jupyter/annovar/humandb//hg38_refGene.txt or cannot infer the transcription start site
# WARNING: cannot find annotation for NM_024616 in the genefile /home/jupyter/annovar/humandb//hg38_refGene.txt or cannot infer the transcription start site
# Warning: 70 transcripts are flagged as having potential ORF issues (premature stopcodon or lack of stop codon)
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=avsnp151
# NOTICE: Finished reading 1 column headers for '-dbtype avsnp151'
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype avsnp151 -buildver hg38 -outfile all_ancestries_annotated to_annotate.txt /home/jupyter/annovar/humandb/ -otherinfo>
# NOTICE: Output file with variants matching filtering criteria is written to all_ancestries_annotated.hg38_avsnp151_dropped, and output file with other variants is written to all_ancestries_annotated.hg38_avsnp151_filtered
# NOTICE: Processing next batch with 4733167 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 574390
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4729047 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 597682
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4730740 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 587800
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4738742 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 577879
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4741167 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 563763
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4755884 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 551741
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4774362 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 478318
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4733871 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 560645
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4733968 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 531488
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4741508 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 597376
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4732335 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 584743
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4738262 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 584831
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4733882 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 590794
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4736378 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 557212
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4737820 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 539802
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4735123 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 594403
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4721423 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 610477
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4751792 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 542881
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4744366 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 575327
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4736859 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 596652
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4733028 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 575941
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4752291 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 580360
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4731300 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 591098
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4733231 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 577611
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4745364 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 555828
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4726801 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 597782
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4735569 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 588090
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 4738957 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 590559
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Processing next batch with 1216352 unique variants in 1285793 input lines
# NOTICE: Database index loaded. Total number of bins is 28835218 and the number of bins to be scanned is 150663
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_avsnp151.txt...Done
# NOTICE: Variants with invalid input format are written to all_ancestries_annotated.invalid_input
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20240917
# NOTICE: Finished reading 13 column headers for '-dbtype clinvar_20240917'
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20240917 -buildver hg38 -outfile all_ancestries_annotated to_annotate.txt /home/jupyter/annovar/humandb/ -otherinfo>
# NOTICE: the --dbtype clinvar_20240917 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to all_ancestries_annotated.hg38_clinvar_20240917_dropped, and output file with other variants is written to all_ancestries_annotated.hg38_clinvar_20240917_filtered
# NOTICE: Processing next batch with 4733167 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4569
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4729047 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4318
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4730740 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3267
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4738742 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3775
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4741167 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4996
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4755884 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 5266
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4774362 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4464
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4733871 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 7843
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4733968 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 8034
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4741508 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 5801
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4732335 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4281
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4738262 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4879
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4733882 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2911
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4736378 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3365
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4737820 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 5418
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4735123 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2457
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4721423 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3854
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4751792 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 4175
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4744366 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3197
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4736859 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3684
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4733028 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2446
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4752291 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3686
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4731300 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2033
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4733231 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2063
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4745364 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2382
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4726801 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 2844
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4735569 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3038
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 4738957 unique variants in 5000000 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 3933
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Processing next batch with 1216352 unique variants in 1285793 input lines
# NOTICE: Database index loaded. Total number of bins is 174536 and the number of bins to be scanned is 459
# NOTICE: Scanning filter database /home/jupyter/annovar/humandb/hg38_clinvar_20240917.txt...Done
# NOTICE: Variants with invalid input format are written to all_ancestries_annotated.invalid_input
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to all_ancestries_annotated.hg38_multianno.txt

# %%
# command to run CADD score annotations
# - note: this was run after the clinvar annotations were run and manually appended to the ClinVar annotations
#         to run this in the initial run with the ClinVar annotations, include the database in the prior command

# !/home/jupyter/annovar/table_annovar.pl to_annotate.txt /home/jupyter/annovar/humandb/ -buildver hg38 -out all_ancestries_annotated_cadd -protocol refGene,avsnp151,dbnsfp33a -operation g,f,f -nastring .

# %%
# check that annotation files were created

# !ls -lh all_ancestries*
# Out:
# -rw-r--r-- 1 jupyter jupyter 2.5G Oct  9 23:11 all_ancestries.txt
# -rw-r--r-- 1 jupyter jupyter 4.1G Oct 10 17:06 all_ancestries_annotated.hg38_avsnp150_dropped
# -rw-r--r-- 1 jupyter jupyter 1.2G Oct 10 17:06 all_ancestries_annotated.hg38_avsnp150_filtered
# -rw-r--r-- 1 jupyter jupyter 5.6G Oct 16 06:54 all_ancestries_annotated.hg38_avsnp151_dropped
# -rw-r--r-- 1 jupyter jupyter 348M Oct 16 06:54 all_ancestries_annotated.hg38_avsnp151_filtered
# -rw-r--r-- 1 jupyter jupyter  85M Oct 10 17:49 all_ancestries_annotated.hg38_clinvar_20221231_dropped
# -rw-r--r-- 1 jupyter jupyter 3.5G Oct 10 17:49 all_ancestries_annotated.hg38_clinvar_20221231_filtered
# -rw-r--r-- 1 jupyter jupyter 138M Oct 16 07:40 all_ancestries_annotated.hg38_clinvar_20240917_dropped
# -rw-r--r-- 1 jupyter jupyter 3.5G Oct 16 07:40 all_ancestries_annotated.hg38_clinvar_20240917_filtered
# -rw-r--r-- 1 jupyter jupyter 412M Oct 11 01:13 all_ancestries_annotated.hg38_dbnsfp33a_dropped
# -rw-r--r-- 1 jupyter jupyter 3.5G Oct 11 01:13 all_ancestries_annotated.hg38_dbnsfp33a_filtered
# -rw-r--r-- 1 jupyter jupyter  14G Oct 16 08:22 all_ancestries_annotated.hg38_multianno.txt
# -rw-r--r-- 1 jupyter jupyter 221M Oct 16 07:40 all_ancestries_annotated.invalid_input
# -rw-r--r-- 1 jupyter jupyter 8.9K Oct 16 07:40 all_ancestries_annotated.log
# -rw-r--r-- 1 jupyter jupyter 279M Oct 16 05:08 all_ancestries_annotated.refGene.exonic_variant_function
# -rw-r--r-- 1 jupyter jupyter 277M Oct 16 05:06 all_ancestries_annotated.refGene.exonic_variant_function.orig
# -rw-r--r-- 1 jupyter jupyter  69M Oct 16 05:08 all_ancestries_annotated.refGene.fa
# -rw-r--r-- 1 jupyter jupyter 221M Oct 16 05:06 all_ancestries_annotated.refGene.invalid_input
# -rw-r--r-- 1 jupyter jupyter  14K Oct 16 05:06 all_ancestries_annotated.refGene.log
# -rw-r--r-- 1 jupyter jupyter 7.9G Oct 16 05:06 all_ancestries_annotated.refGene.variant_function

# %% [markdown]
# ## filter for pathogenic variants

# %%
# genes of interest (PD genes)
genes = ['SNCA', 'PRKN', 'PARK7', 'LRRK2', 'PINK1', 'ATP13A2', 'FBX07', 'GBA', 'PLA2G6', 'VPS35', 'POLG', 'DNAJC6', 'SYNJ1', 'VPS13C', \
         'UCHL1', 'HTRA2', 'GIGYF2', 'EIF4G1', 'DNAJC13', 'TMEM230', 'LRP10']

# create file with these genes to awk from
with open(f'{workspace}/genes_of_interest.txt', 'w') as f:
    for gene in genes:
        f.write(f'{gene}\n')
f.close()

# %%
# get only variants that are within genes of interest

# !grep -F -f {workspace}/genes_of_interest.txt {workspace}/bfiles/all_ancestries_annotated.hg38_multianno.txt > {workspace}/annotated_selectedgenes.txt

# %%
# get column names
annotated_selected_genes_file = open(f'{workspace}/bfiles/all_ancestries_annotated.hg38_multianno.txt', 'r')
col_names = annotated_selected_genes_file.readline().split('\t')
print(col_names)

want_cols = ['Chr','Start','End','Ref','Alt','Gene.refGene','avsnp151','CLNALLELEID','CLNDN','CLNDISDB','CLNREVSTAT','CLNSIG']
# Out:
# ['Chr', 'Start', 'End', 'Ref', 'Alt', 'Func.refGene', 'Gene.refGene', 'GeneDetail.refGene', 'ExonicFunc.refGene', 'AAChange.refGene', 'avsnp151', 'CLNALLELEID', 'CLNDN', 'CLNDISDB', 'CLNREVSTAT', 'CLNSIG', 'ONCDN', 'ONCDISDB', 'ONCREVSTAT', 'ONC', 'SCIDN', 'SCIDISDB', 'SCIREVSTAT', 'SCI\n']

# %%
annotated_select_genes = pd.read_csv(f'{workspace}/annotated_selectedgenes.txt', sep='\t', header=None, \
                                     names=col_names, usecols=want_cols)
annotated_select_genes
# Out:
#           Chr      Start        End Ref Alt     Gene.refGene      avsnp151  \
# 0       chr12   40168848   40168848   A   G  LINC02471;LRRK2             .
# 1       chr12   40168854   40168854   C   T  LINC02471;LRRK2   rs541787948
# 2       chr12   40168868   40168868   C   A  LINC02471;LRRK2   rs535940699
# 3       chr12   40168875   40168875   T  TC  LINC02471;LRRK2   rs576168793
# 4       chr12   40168880   40168880   C   A  LINC02471;LRRK2  rs1005738941
# ...       ...        ...        ...  ..  ..              ...           ...
# 464769   chr6  162727742  162727742   C   G             PRKN  rs1362063712
# 464770   chr6  162727743  162727743   A   G             PRKN   rs751054800
# 464771   chr6  162727745  162727745   C   A             PRKN   rs756731328
# 464772   chr6  162727753  162727753   C   T             PRKN   rs556535340
# 464773   chr6  162727764  162727764   C   T             PRKN  rs1232075505
#
#        CLNALLELEID                                             CLNDN  \
# 0                .                                                 .
# 1                .                                                 .
# 2                .                                                 .
# 3                .                                                 .
# 4                .                                                 .
# ...            ...                                               ...
# 464769           .                                                 .
# 464770           .                                                 .
# 464771           .                                                 .
# 464772      895664  Autosomal_recessive_juvenile_Parkinson_disease_2
# 464773           .                                                 .
#
#                                                  CLNDISDB  \
# 0                                                       .
# 1                                                       .
# 2                                                       .
# 3                                                       .
# 4                                                       .
# ...                                                   ...
# 464769                                                  .
# 464770                                                  .
# 464771                                                  .
# 464772  MONDO:MONDO:0010820,MedGen:C1868675,OMIM:60011...
# 464773                                                  .
#
#                                  CLNREVSTAT                  CLNSIG
# 0                                         .                       .
# 1                                         .                       .
# 2                                         .                       .
# 3                                         .                       .
# 4                                         .                       .
# ...                                     ...                     ...
# 464769                                    .                       .
# 464770                                    .                       .
# 464771                                    .                       .
# 464772  criteria_provided,_single_submitter  Uncertain_significance
# 464773                                    .                       .
#
# [464774 rows x 12 columns]

# %%
# extract only the variants that have a clinical significant == "Pathogenic"

pathogenic_vars = annotated_select_genes[annotated_select_genes['CLNSIG']=='Pathogenic']

# exclude the variants in POLG2 (not a gene of interest)
pathogenic_vars = pathogenic_vars[~(pathogenic_vars['Gene.refGene']=='POLG2')]

# save list of pathogenic variants to an output file
pathogenic_vars.to_csv(f'{workspace}/annotated_pathogenic_vars.txt', sep='\t', header=True, index=False)
pathogenic_vars
# Out:
# (34, 24)
#           Chr      Start        End Ref Alt Func.refGene Gene.refGene  \
# 9898    chr12   40310434   40310434   C   T       exonic        LRRK2
# 47879   chr15   89319225   89319225   T   A     intronic         POLG
# 48145   chr15   89321780   89321780   G   A       exonic         POLG
# 48146   chr15   89321792   89321792   C   T       exonic         POLG
# 48530   chr15   89325610   89325610   G   A       exonic         POLG
# 48542   chr15   89325679   89325679   G   A       exonic         POLG
# 48682   chr15   89327166   89327166   C   T     splicing         POLG
# 48685   chr15   89327201   89327201   C   T       exonic         POLG
# 48843   chr15   89329041   89329041   G   A       exonic         POLG
# 70751    chr1  155235196  155235196   G   A       exonic          GBA
# 70835    chr1  155236295  155236295   G   A       exonic          GBA
# 70948    chr1  155237453  155237453   C   T       exonic          GBA
# 71013    chr1  155238206  155238206   A   C       exonic          GBA
# 71017    chr1  155238215  155238215   T   C       exonic          GBA
# 71038    chr1  155238630  155238630   G   A       exonic          GBA
# 71134    chr1  155239934  155239934   G   A       exonic          GBA
# 72210    chr1   16988455   16988455   C   T       exonic      ATP13A2
# 72328    chr1   16989961   16989961   G   A       exonic      ATP13A2
# 72536    chr1   16992345   16992345   G   A       exonic      ATP13A2
# 72904    chr1   16996059   16996059   G   A       exonic      ATP13A2
# 73729    chr1   17005450   17005450   C   T       exonic      ATP13A2
# 76909    chr1   20645640   20645640   T   C       exonic        PINK1
# 77218    chr1   20649109   20649109   C   T       exonic        PINK1
# 77228    chr1   20649217   20649217   C   T       exonic        PINK1
# 104335  chr20    5100921    5100921   C   A       exonic      TMEM230
# 113919  chr21   32726907   32726907   C   A       exonic        SYNJ1
# 114566  chr22   38115658   38115658   G   A       exonic       PLA2G6
# 116177  chr22   38132917   38132917   C   A       exonic       PLA2G6
# 119356  chr22   38169318   38169318   G   A       exonic       PLA2G6
# 346356   chr6  161350214  161350214   G   C     intronic         PRKN
# 382697   chr6  161785793  161785793   C   G       exonic         PRKN
# 382708   chr6  161785839  161785839   A   T       exonic         PRKN
# 440038   chr6  162443314  162443314   A   T       exonic         PRKN
# 440042   chr6  162443356  162443356   C   G       exonic         PRKN
#
#                                        GeneDetail.refGene ExonicFunc.refGene  \
# 9898                                                    .  nonsynonymous SNV
# 47879                                                   .                  .
# 48145                                                   .  nonsynonymous SNV
# 48146                                                   .  nonsynonymous SNV
# 48530                                                   .  nonsynonymous SNV
# 48542                                                   .  nonsynonymous SNV
# 48682   NM_001126131:exon7:c.1433+1G>A;NM_002693:exon7...                  .
# 48685                                                   .  nonsynonymous SNV
# 48843                                                   .  nonsynonymous SNV
# 70751                                                   .  nonsynonymous SNV
# 70835                                                   .  nonsynonymous SNV
# 70948                                                   .  nonsynonymous SNV
# 71013                                                   .  nonsynonymous SNV
# 71017                                                   .  nonsynonymous SNV
# 71038                                                   .  nonsynonymous SNV
# 71134                                                   .  nonsynonymous SNV
# 72210                                                   .  nonsynonymous SNV
# 72328                                                   .           stopgain
# 72536                                                   .           stopgain
# 72904                                                   .           stopgain
# 73729                                                   .           stopgain
# 76909                                                   .  nonsynonymous SNV
# 77218                                                   .           stopgain
# 77228                                                   .           stopgain
# 104335                                                  .  nonsynonymous SNV
# 113919                                                  .           stopgain
# 114566                                                  .           stopgain
# 116177                                                  .  nonsynonymous SNV
# 119356                                                  .           stopgain
# 346356                                                  .                  .
# 382697                                                  .  nonsynonymous SNV
# 382708                                                  .           stopgain
# 440038                                                  .  nonsynonymous SNV
# 440042                                                  .  nonsynonymous SNV
#
#                                          AAChange.refGene  ...  \
# 9898             LRRK2:NM_198578:exon31:c.C4321T:p.R1441C  ...
# 47879                                                   .  ...
# 48145   POLG:NM_001126131:exon16:c.C2554T:p.R852C,POLG...  ...
# 48146   POLG:NM_001126131:exon16:c.G2542A:p.G848S,POLG...  ...
# 48530   POLG:NM_001126131:exon10:c.C1789T:p.R597W,POLG...  ...
# 48542   POLG:NM_001126131:exon10:c.C1720T:p.R574W,POLG...  ...
# 48682                                                   .  ...
# 48685   POLG:NM_001126131:exon7:c.G1399A:p.A467T,POLG:...  ...
# 48843   POLG:NM_001126131:exon4:c.C925T:p.R309C,POLG:N...  ...
# 70751   GBA:NM_001171811:exon9:c.C1243T:p.R415C,GBA:NM...  ...
# 70835   GBA:NM_001171811:exon7:c.C913T:p.R305W,GBA:NM_...  ...
# 70948   GBA:NM_001171811:exon6:c.G626A:p.R209Q,GBA:NM_...  ...
# 71013   GBA:NM_001171811:exon5:c.T428G:p.V143G,GBA:NM_...  ...
# 71017   GBA:NM_001171811:exon5:c.A419G:p.N140S,GBA:NM_...  ...
# 71038   GBA:NM_001171811:exon4:c.C214T:p.R72W,GBA:NM_0...  ...
# 71134   GBA:NM_000157:exon3:c.C259T:p.R87W,GBA:NM_0011...  ...
# 72210   ATP13A2:NM_001141974:exon23:c.G2497A:p.G833R,A...  ...
# 72328   ATP13A2:NM_001141973:exon22:c.C2440T:p.R814X,A...  ...
# 72536   ATP13A2:NM_001141973:exon18:c.C1888T:p.Q630X,A...  ...
# 72904   ATP13A2:NM_001141973:exon15:c.C1444T:p.R482X,A...  ...
# 73729   ATP13A2:NM_001141973:exon3:c.G212A:p.W71X,ATP1...  ...
# 76909              PINK1:NM_032409:exon5:c.T1040C:p.L347P  ...
# 77218              PINK1:NM_032409:exon7:c.C1366T:p.Q456X  ...
# 77228              PINK1:NM_032409:exon7:c.C1474T:p.R492X  ...
# 104335  TMEM230:NM_001009925:exon4:c.G233T:p.R78L,TMEM...  ...
# 113919               SYNJ1:NM_003895:exon2:c.G106T:p.E36X  ...
# 114566  PLA2G6:NM_001004426:exon13:c.C1741T:p.R581X,PL...  ...
# 116177  PLA2G6:NM_001349868:exon6:c.G313T:p.D105Y,PLA2...  ...
# 119356  PLA2G6:NM_001004426:exon2:c.C109T:p.R37X,PLA2G...  ...
# 346356                                                  .  ...
# 382697  PRKN:NM_013988:exon4:c.G403C:p.G135R,PRKN:NM_0...  ...
# 382708  PRKN:NM_013988:exon4:c.T357A:p.C119X,PRKN:NM_0...  ...
# 440038  PRKN:NM_004562:exon2:c.T167A:p.V56E,PRKN:NM_01...  ...
# 440042  PRKN:NM_004562:exon2:c.G125C:p.R42P,PRKN:NM_01...  ...
#
#                                                CLNREVSTAT      CLNSIG ONCDN  \
# 9898    criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 47879   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48145   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48146   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48530   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48542   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48682   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48685   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 48843   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 70751   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 70835                 criteria_provided,_single_submitter  Pathogenic     .
# 70948   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 71013                 criteria_provided,_single_submitter  Pathogenic     .
# 71017   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 71038   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 71134   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 72210                      no_assertion_criteria_provided  Pathogenic     .
# 72328   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 72536   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 72904   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 73729   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 76909   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 77218   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 77228   criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 104335                criteria_provided,_single_submitter  Pathogenic     .
# 113919                criteria_provided,_single_submitter  Pathogenic     .
# 114566  criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 116177  criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 119356  criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 346356                criteria_provided,_single_submitter  Pathogenic     .
# 382697                criteria_provided,_single_submitter  Pathogenic     .
# 382708  criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 440038  criteria_provided,_multiple_submitters,_no_con...  Pathogenic     .
# 440042                criteria_provided,_single_submitter  Pathogenic     .
#
#        ONCDISDB ONCREVSTAT ONC SCIDN SCIDISDB SCIREVSTAT SCI\n
# 9898          .          .   .     .        .          .     .
# 47879         .          .   .     .        .          .     .
# 48145         .          .   .     .        .          .     .
# 48146         .          .   .     .        .          .     .
# 48530         .          .   .     .        .          .     .
# 48542         .          .   .     .        .          .     .
# 48682         .          .   .     .        .          .     .
# 48685         .          .   .     .        .          .     .
# 48843         .          .   .     .        .          .     .
# 70751         .          .   .     .        .          .     .
# 70835         .          .   .     .        .          .     .
# 70948         .          .   .     .        .          .     .
# 71013         .          .   .     .        .          .     .
# 71017         .          .   .     .        .          .     .
# 71038         .          .   .     .        .          .     .
# 71134         .          .   .     .        .          .     .
# 72210         .          .   .     .        .          .     .
# 72328         .          .   .     .        .          .     .
# 72536         .          .   .     .        .          .     .
# 72904         .          .   .     .        .          .     .
# 73729         .          .   .     .        .          .     .
# 76909         .          .   .     .        .          .     .
# 77218         .          .   .     .        .          .     .
# 77228         .          .   .     .        .          .     .
# 104335        .          .   .     .        .          .     .
# 113919        .          .   .     .        .          .     .
# 114566        .          .   .     .        .          .     .
# 116177        .          .   .     .        .          .     .
# 119356        .          .   .     .        .          .     .
# 346356        .          .   .     .        .          .     .
# 382697        .          .   .     .        .          .     .
# 382708        .          .   .     .        .          .     .
# 440038        .          .   .     .        .          .     .
# 440042        .          .   .     .        .          .     .
#
# [34 rows x 24 columns]

# %%
# check how many of the pathogenic variants have the term "Parkinson" in ClinVar's 'CLNDN' field

pd_pathogenic_vars = pathogenic_vars[pathogenic_vars['CLNDN'].str.contains("parkinson", case=False, regex=False)]
pd_pathogenic_vars
# Out:
#           Chr      Start        End Ref Alt Gene.refGene      avsnp151  \
# 9898    chr12   40310434   40310434   C   T        LRRK2    rs33939927
# 70751    chr1  155235196  155235196   G   A          GBA    rs80356771
# 70948    chr1  155237453  155237453   C   T          GBA    rs78973108
# 71017    chr1  155238215  155238215   T   C          GBA      rs364897
# 71134    chr1  155239934  155239934   G   A          GBA     rs1141814
# 76909    chr1   20645640   20645640   T   C        PINK1    rs28940285
# 77218    chr1   20649109   20649109   C   T        PINK1    rs45539432
# 77228    chr1   20649217   20649217   C   T        PINK1    rs34208370
# 113919  chr21   32726907   32726907   C   A        SYNJ1  rs1040540690
# 116177  chr22   38132917   38132917   C   A       PLA2G6   rs199935023
# 382697   chr6  161785793  161785793   C   G         PRKN   rs751037529
# 440038   chr6  162443314  162443314   A   T         PRKN   rs137853059
#
#        CLNALLELEID                                              CLNDN  \
# 9898         16977  not_provided|Autosomal_dominant_Parkinson_dise...
# 70751        19334  Parkinson_disease,_late-onset|Gaucher_disease-...
# 70948        19367  Parkinson_disease,_late-onset|Gaucher_disease-...
# 71017        19353  Gaucher_disease-ophthalmoplegia-cardiovascular...
# 71134        19360  Parkinson_disease,_late-onset|Gaucher_disease-...
# 76909        17447  Autosomal_recessive_early-onset_Parkinson_dise...
# 77218        17454  not_provided|Autosomal_recessive_early-onset_P...
# 77228       425331  Autosomal_recessive_early-onset_Parkinson_dise...
# 113919     1393547  Developmental_and_epileptic_encephalopathy,_53...
# 116177       39328  Infantile_neuroaxonal_dystrophy|Autosomal_rece...
# 382697      395419  Autism_spectrum_disorder|not_provided|Autosoma...
# 440038       22086  not_provided|Autosomal_recessive_juvenile_Park...
#
#                                                  CLNDISDB  \
# 9898    MedGen:C3661900|MONDO:MONDO:0011764,MedGen:C18...
# 70751   MONDO:MONDO:0008199,MedGen:C3160718,OMIM:16860...
# 70948   MONDO:MONDO:0008199,MedGen:C3160718,OMIM:16860...
# 71017   MONDO:MONDO:0009268,MedGen:C1856476,OMIM:23100...
# 71134   MONDO:MONDO:0008199,MedGen:C3160718,OMIM:16860...
# 76909   MONDO:MONDO:0011613,MedGen:C1853833,OMIM:60590...
# 77218   MedGen:C3661900|MONDO:MONDO:0011613,MedGen:C18...
# 77228   MONDO:MONDO:0011613,MedGen:C1853833,OMIM:60590...
# 113919  MONDO:MONDO:0033362,MedGen:C4479313,OMIM:61738...
# 116177  MONDO:MONDO:0024457,MedGen:C0270724,OMIM:25660...
# 382697  MONDO:MONDO:0005258,MeSH:D000067877,MedGen:C15...
# 440038  MedGen:CN517202|MONDO:MONDO:0010820,MedGen:C18...
#
#                                                CLNREVSTAT      CLNSIG
# 9898    criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 70751   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 70948   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 71017   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 71134   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 76909   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 77218   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 77228   criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 113919                criteria_provided,_single_submitter  Pathogenic
# 116177  criteria_provided,_multiple_submitters,_no_con...  Pathogenic
# 382697                criteria_provided,_single_submitter  Pathogenic
# 440038  criteria_provided,_multiple_submitters,_no_con...  Pathogenic

# %%
# check the clinical significance counts for all PD genes of interest

for gene in ['GBA','ATP13A2','PINK1','LRRK2','VPS13C','POLG','VPS35','DNAJC6','PARK7','SYNJ1', \
             'FBXO7','PLA2G6','HTRA2','DNAJC13','UCHL1','SNCA','PRKN','GIGYF2','EIF4G1','TMEM230','LRP10']:
    path_vars_gene = annotated_select_genes[(annotated_select_genes['Gene.refGene'].str.contains(gene))]
    print(gene, path_vars_gene.CLNSIG.value_counts(), '\n')
# Out:
# GBA CLNSIG
# .                                                           107049
# Uncertain_significance                                          43
# Likely_benign                                                   17
# Conflicting_classifications_of_pathogenicity                    13
# Pathogenic                                                       7
# Pathogenic/Likely_pathogenic                                     6
# Likely_pathogenic                                                3
# Benign                                                           3
# Benign/Likely_benign                                             2
# Pathogenic/Likely_pathogenic|risk_factor                         1
# Conflicting_classifications_of_pathogenicity|risk_factor         1
# Conflicting_classifications_of_pathogenicity|other               1
# Name: count, dtype: int64
#
# ATP13A2 CLNSIG
# .                                               2805
# Likely_benign                                    157
# Uncertain_significance                           125
# Conflicting_classifications_of_pathogenicity      75
# Benign                                            30
# Benign/Likely_benign                              25
# Pathogenic                                         5
# Pathogenic/Likely_pathogenic                       2
# Likely_pathogenic                                  1
# Name: count, dtype: int64
#
# PINK1 CLNSIG
# .                                               2519
# Uncertain_significance                            82
# Likely_benign                                     45
# Conflicting_classifications_of_pathogenicity      27
# Benign                                            27
# Benign/Likely_benign                              14
# Pathogenic                                         3
# Pathogenic/Likely_pathogenic                       2
# Uncertain_risk_allele                              1
# Name: count, dtype: int64
#
# LRRK2 CLNSIG
# .                                                           15330
# Likely_benign                                                 183
# Uncertain_significance                                        141
# Benign                                                        128
# Benign/Likely_benign                                           43
# Conflicting_classifications_of_pathogenicity                   39
# not_provided                                                    2
# Pathogenic                                                      1
# Pathogenic/Likely_pathogenic|risk_factor                        1
# Conflicting_classifications_of_pathogenicity|risk_factor        1
# Name: count, dtype: int64
#
# VPS13C CLNSIG
# .                                               28405
# Benign                                            171
# Likely_benign                                     149
# Uncertain_significance                            131
# Benign/Likely_benign                               14
# Conflicting_classifications_of_pathogenicity        9
# Likely_pathogenic                                   6
# Pathogenic/Likely_pathogenic                        1
# Name: count, dtype: int64
#
# POLG CLNSIG
# .                                               31956
# Uncertain_significance                            203
# Likely_benign                                     165
# Conflicting_classifications_of_pathogenicity      142
# Benign                                             67
# Benign/Likely_benign                               32
# Pathogenic/Likely_pathogenic                       10
# Pathogenic                                          9
# Likely_pathogenic                                   2
# Name: count, dtype: int64
#
# VPS35 CLNSIG
# .                                               15315
# Likely_benign                                      27
# Uncertain_significance                             25
# Benign                                             22
# Benign/Likely_benign                                6
# Conflicting_classifications_of_pathogenicity        4
# Name: count, dtype: int64
#
# DNAJC6 CLNSIG
# .                                               13300
# Uncertain_significance                             57
# Likely_benign                                      53
# Benign                                             40
# Benign/Likely_benign                                9
# Conflicting_classifications_of_pathogenicity        2
# not_provided                                        1
# Name: count, dtype: int64
#
# PARK7 CLNSIG
# .                                               5786
# Benign                                            25
# Uncertain_significance                            21
# Likely_benign                                     10
# Benign/Likely_benign                               4
# Likely_pathogenic                                  1
# Conflicting_classifications_of_pathogenicity       1
# Name: count, dtype: int64
#
# SYNJ1 CLNSIG
# .                                               8167
# Likely_benign                                    161
# Uncertain_significance                           140
# Benign                                            33
# Conflicting_classifications_of_pathogenicity      12
# Benign/Likely_benign                               9
# Pathogenic                                         1
# Name: count, dtype: int64
#
# FBXO7 Series([], Name: count, dtype: int64)
#
# PLA2G6 CLNSIG
# .                                               7765
# Likely_benign                                    110
# Uncertain_significance                            94
# Benign                                            50
# Conflicting_classifications_of_pathogenicity      46
# Benign/Likely_benign                               9
# Pathogenic                                         3
# Likely_pathogenic                                  1
# Pathogenic/Likely_pathogenic                       1
# Name: count, dtype: int64
#
# HTRA2 CLNSIG
# .                                               173
# Likely_benign                                    29
# Uncertain_significance                           25
# Benign                                           10
# Benign/Likely_benign                              5
# Conflicting_classifications_of_pathogenicity      5
# Name: count, dtype: int64
#
# DNAJC13 CLNSIG
# .                                               13709
# Benign                                             96
# Uncertain_significance                             39
# Likely_benign                                      18
# Benign/Likely_benign                                5
# Conflicting_classifications_of_pathogenicity        1
# Name: count, dtype: int64
#
# UCHL1 CLNSIG
# .                                               11441
# Likely_benign                                      26
# Benign                                             21
# Uncertain_significance                             16
# Benign/Likely_benign                                4
# Conflicting_classifications_of_pathogenicity        3
# Name: count, dtype: int64
#
# SNCA CLNSIG
# .                                               44894
# Uncertain_significance                             25
# Likely_benign                                      25
# Benign                                             19
# Benign/Likely_benign                                5
# Conflicting_classifications_of_pathogenicity        3
# Name: count, dtype: int64
#
# PRKN CLNSIG
# .                                               124277
# Uncertain_significance                              68
# Likely_benign                                       60
# Benign                                              41
# Conflicting_classifications_of_pathogenicity        18
# Benign/Likely_benign                                12
# Pathogenic                                           5
# Pathogenic/Likely_pathogenic                         4
# Name: count, dtype: int64
#
# GIGYF2 CLNSIG
# .                                               14086
# Benign                                             38
# Uncertain_significance                             23
# Likely_benign                                      15
# risk_factor                                         3
# Conflicting_classifications_of_pathogenicity        1
# Benign/Likely_benign                                1
# Name: count, dtype: int64
#
# EIF4G1 CLNSIG
# .                         2185
# Uncertain_significance      28
# Benign                      26
# Likely_benign               21
# Benign/Likely_benign         3
# risk_factor                  2
# Name: count, dtype: int64
#
# TMEM230 CLNSIG
# .                                               8630
# Likely_benign                                      9
# Benign                                             6
# Uncertain_significance                             6
# Pathogenic                                         1
# Conflicting_classifications_of_pathogenicity       1
# Name: count, dtype: int64
#
# LRP10 CLNSIG
# .                         2817
# Uncertain_significance      18
# Benign                      11
# Likely_benign                9
# Name: count, dtype: int64

# %%
# save just variant IDs to calculate freqs from

annotated_pathogenic_vars = pd.read_csv(f'{workspace}/annotated_pathogenic_vars.txt', sep='\t')
annotated_pathogenic_vars['snpID'] = annotated_pathogenic_vars['Chr'] + ':' \
                                     + annotated_pathogenic_vars['Start'].astype(str) + ':' \
                                     + annotated_pathogenic_vars['Ref'] + ':' \
                                     + annotated_pathogenic_vars['Alt']
annotated_pathogenic_vars['snpID'].to_csv(f'{workspace}/pathogenic_variant_IDs.txt', header=None, index=None)

# %%
# extract pathogenic variants from each ancestry plink files

for anc in ancestries:
    plink_cmd = f'{plink_exec} --bfile {workspace}/bfiles/MERGE_{anc} --extract {workspace}/pathogenic_variant_IDs.txt --make-bed --out {workspace}/bfiles/{anc}_r7_pathogenic_only'
    # !{plink_cmd}
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_AAC
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 34460677 variants loaded from .bim file.
# 1111 people (455 males, 656 females) loaded from .fam.
# 1086 phenotype values loaded from .fam.
# --extract: 2 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1111 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99955.
# 2 variants and 1111 people pass filters and QC.
# Among remaining phenotypes, 285 are cases and 801 are controls.  (25 phenotypes
# are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_AFR
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 39494539 variants loaded from .bim file.
# 2643 people (1480 males, 1163 females) loaded from .fam.
# 2621 phenotype values loaded from .fam.
# --extract: 8 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2643 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999054.
# 8 variants and 2643 people pass filters and QC.
# Among remaining phenotypes, 942 are cases and 1679 are controls.  (22
# phenotypes are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_AJ
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 14332784 variants loaded from .bim file.
# 2655 people (1648 males, 1007 females) loaded from .fam.
# 1703 phenotype values loaded from .fam.
# --extract: 2 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2655 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999812.
# 2 variants and 2655 people pass filters and QC.
# Among remaining phenotypes, 1292 are cases and 411 are controls.  (952
# phenotypes are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_AMR
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 20873391 variants loaded from .bim file.
# 646 people (363 males, 283 females) loaded from .fam.
# 613 phenotype values loaded from .fam.
# --extract: 3 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 646 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999484.
# 3 variants and 646 people pass filters and QC.
# Among remaining phenotypes, 458 are cases and 155 are controls.  (33 phenotypes
# are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_CAH
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 31670734 variants loaded from .bim file.
# 851 people (446 males, 405 females) loaded from .fam.
# 827 phenotype values loaded from .fam.
# --extract: 2 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 851 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 2 variants and 851 people pass filters and QC.
# Among remaining phenotypes, 525 are cases and 302 are controls.  (24 phenotypes
# are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_CAS
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 19008457 variants loaded from .bim file.
# 903 people (439 males, 464 females) loaded from .fam.
# 895 phenotype values loaded from .fam.
# --extract: 2 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 903 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 2 variants and 903 people pass filters and QC.
# Among remaining phenotypes, 552 are cases and 343 are controls.  (8 phenotypes
# are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_EAS
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 28698631 variants loaded from .bim file.
# 5167 people (3278 males, 1889 females) loaded from .fam.
# 5123 phenotype values loaded from .fam.
# --extract: 5 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 5167 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.998916.
# 5 variants and 5167 people pass filters and QC.
# Among remaining phenotypes, 2662 are cases and 2461 are controls.  (44
# phenotypes are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_EUR
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 91242179 variants loaded from .bim file.
# 38839 people (23296 males, 15543 females) loaded from .fam.
# 30412 phenotype values loaded from .fam.
# --extract: 19 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 38839 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.841842.
# 19 variants and 38839 people pass filters and QC.
# Among remaining phenotypes, 21198 are cases and 9214 are controls.  (8427
# phenotypes are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_FIN
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 7522443 variants loaded from .bim file.
# 114 people (53 males, 61 females) loaded from .fam.
# 106 phenotype values loaded from .fam.
# --extract: 1 variant remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 114 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991228.
# 1 variant and 114 people pass filters and QC.
# Among remaining phenotypes, 98 are cases and 8 are controls.  (8 phenotypes are
# missing.)
# --make-bed to /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_MDE
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 18471227 variants loaded from .bim file.
# 581 people (369 males, 212 females) loaded from .fam.
# 536 phenotype values loaded from .fam.
# --extract: 3 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 581 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999426.
# 3 variants and 581 people pass filters and QC.
# Among remaining phenotypes, 311 are cases and 225 are controls.  (45 phenotypes
# are missing.)
# --make-bed to /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only.bed +
# /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only.bim +
# /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/bfiles/SAS_r7_pathogenic_only.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MERGE_SAS
#   --extract /home/jupyter/workspace/pathogenic_variant_IDs.txt
#   --make-bed
#   --out /home/jupyter/workspace/bfiles/SAS_r7_pathogenic_only
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 16746115 variants loaded from .bim file.
# 635 people (408 males, 227 females) loaded from .fam.
# 609 phenotype values loaded from .fam.
# Error: No variants remaining after --extract.

# %%
# check how many pathogenic variants in each ancestry

for anc in ancestries:
    bim_fn = f'{workspace}/bfiles/{anc}_r7_pathogenic_only.bim'
    if os.path.isfile(bim_fn):
        bim = pd.read_csv(bim_fn, sep='\s+', header=None, names=['CHR','snpID','DIST','POS','ALT','REF'])
        print(anc, bim.shape)
    else:
        print(anc, "no pathogenic vars")
# Out:
# AAC (2, 6)
# AFR (8, 6)
# AJ (2, 6)
# AMR (3, 6)
# CAH (2, 6)
# CAS (2, 6)
# EAS (5, 6)
# EUR (19, 6)
# FIN (1, 6)
# MDE (3, 6)
# SAS no pathogenic vars

# %%
# run frequencies for case/control per ancestry

for anc in ancestries:
    anc_path = f'{workspace}/bfiles/{anc}_r7_pathogenic_only'
    if os.path.isfile(f'{anc_path}.bim'):
        plink_cmd = f'{plink_exec} --bfile {anc_path} --freq case-control --out {workspace}/freqs/{anc}_path_vars_case_control'
        # !{plink_cmd}
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AAC_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/AAC_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 1111 people (455 males, 656 females) loaded from .fam.
# 1086 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1111 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99955.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/AAC_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AFR_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/AFR_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 8 variants loaded from .bim file.
# 2643 people (1480 males, 1163 females) loaded from .fam.
# 2621 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2643 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999054.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/AFR_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AJ_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/AJ_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 2655 people (1648 males, 1007 females) loaded from .fam.
# 1703 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2655 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999812.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/AJ_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AMR_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/AMR_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 3 variants loaded from .bim file.
# 646 people (363 males, 283 females) loaded from .fam.
# 613 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 646 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999484.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/AMR_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/CAH_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/CAH_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 851 people (446 males, 405 females) loaded from .fam.
# 827 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 851 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/CAH_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/CAS_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/CAS_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 903 people (439 males, 464 females) loaded from .fam.
# 895 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 903 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/CAS_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/EAS_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/EAS_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 5 variants loaded from .bim file.
# 5167 people (3278 males, 1889 females) loaded from .fam.
# 5123 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 5167 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.998916.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/EAS_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/EUR_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/EUR_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 19 variants loaded from .bim file.
# 38839 people (23296 males, 15543 females) loaded from .fam.
# 30412 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 38839 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.841842.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/EUR_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/FIN_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/FIN_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 1 variant loaded from .bim file.
# 114 people (53 males, 61 females) loaded from .fam.
# 106 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 114 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991228.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/FIN_path_vars_case_control.frq.cc .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/MDE_path_vars_case_control.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only
#   --freq case-control
#   --out /home/jupyter/workspace/freqs/MDE_path_vars_case_control
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 3 variants loaded from .bim file.
# 581 people (369 males, 212 females) loaded from .fam.
# 536 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 581 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999426.
# --freq case-control: Phenotype-stratified allele frequencies (founders only)
# written to /home/jupyter/workspace/freqs/MDE_path_vars_case_control.frq.cc .

# %%
# run all frequencies per ancestry

for anc in ancestries:
    anc_path = f'{workspace}/bfiles/{anc}_r7_pathogenic_only'
    if os.path.isfile(f'{anc_path}.bim'):
        plink_cmd = f'{plink_exec} --bfile {anc_path} --freq --out {workspace}/freqs/{anc}_path_vars_all'
        # !{plink_cmd}
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AAC_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AAC_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/AAC_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 1111 people (455 males, 656 females) loaded from .fam.
# 1086 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1111 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99955.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/AAC_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AFR_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AFR_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/AFR_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 8 variants loaded from .bim file.
# 2643 people (1480 males, 1163 females) loaded from .fam.
# 2621 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2643 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999054.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/AFR_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AJ_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AJ_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/AJ_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 2655 people (1648 males, 1007 females) loaded from .fam.
# 1703 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2655 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999812.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/AJ_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/AMR_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/AMR_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/AMR_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 3 variants loaded from .bim file.
# 646 people (363 males, 283 females) loaded from .fam.
# 613 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 646 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999484.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/AMR_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/CAH_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/CAH_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/CAH_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 851 people (446 males, 405 females) loaded from .fam.
# 827 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 851 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/CAH_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/CAS_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/CAS_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/CAS_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 2 variants loaded from .bim file.
# 903 people (439 males, 464 females) loaded from .fam.
# 895 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 903 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/CAS_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/EAS_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/EAS_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/EAS_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 5 variants loaded from .bim file.
# 5167 people (3278 males, 1889 females) loaded from .fam.
# 5123 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 5167 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.998916.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/EAS_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/EUR_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/EUR_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/EUR_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 19 variants loaded from .bim file.
# 38839 people (23296 males, 15543 females) loaded from .fam.
# 30412 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 38839 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.841842.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/EUR_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/FIN_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/FIN_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/FIN_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 1 variant loaded from .bim file.
# 114 people (53 males, 61 females) loaded from .fam.
# 106 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 114 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991228.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/FIN_path_vars_all.frq .
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/freqs/MDE_path_vars_all.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/bfiles/MDE_r7_pathogenic_only
#   --freq
#   --out /home/jupyter/workspace/freqs/MDE_path_vars_all
#
# 209368 MB RAM detected; reserving 104684 MB for main workspace.
# 3 variants loaded from .bim file.
# 581 people (369 males, 212 females) loaded from .fam.
# 536 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 581 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999426.
# --freq: Allele frequencies (founders only) written to
# /home/jupyter/workspace/freqs/MDE_path_vars_all.frq .

# %%
# combine freq calculations

# SAS has no pathogenic vars
all_anc_freqs = pd.DataFrame(columns=['CHR','SNP','A1','A2','MAF','MAF_A','MAF_U'])

for anc in ancestries:
    if os.path.isfile(f'{workspace}/bfiles/{anc}_r7_pathogenic_only.bim'):
        all_freqs = pd.read_csv(f'{workspace}/freqs/{anc}_path_vars_all.frq', sep='\s+', usecols=['CHR','SNP','A1','A2','MAF'])
        case_control_freqs = pd.read_csv(f'{workspace}/freqs/{anc}_path_vars_case_control.frq.cc', sep='\s+', usecols=['CHR','SNP','A1','A2','MAF_A','MAF_U'])
        freqs = pd.merge(all_freqs, case_control_freqs, on=['CHR','SNP','A1','A2'], how='outer')
        all_anc_freqs = all_anc_freqs.merge(freqs, on=['CHR','SNP','A1','A2'], how='outer', suffixes=(None, f'_{anc}'))

all_anc_freqs
# Out:
#     CHR                 SNP A1 A2  MAF MAF_A MAF_U  MAF_AAC  MAF_A_AAC  \
# 0     1  chr1:155235196:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 1     1  chr1:155236295:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 2     1  chr1:155237453:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 3     1  chr1:155238206:A:C  C  A  NaN   NaN   NaN      NaN        NaN
# 4     1  chr1:155238215:T:C  C  T  NaN   NaN   NaN      NaN        NaN
# 5     1  chr1:155238630:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 6     1  chr1:155239934:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 7     1   chr1:16988455:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 8     1   chr1:16989961:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 9     1   chr1:16992345:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 10    1   chr1:16996059:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 11    1   chr1:17005450:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 12    1   chr1:20645640:T:C  C  T  NaN   NaN   NaN      NaN        NaN
# 13    1   chr1:20649109:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 14    1   chr1:20649217:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 15    6  chr6:161350214:G:C  C  G  NaN   NaN   NaN      NaN        NaN
# 16    6  chr6:161785793:C:G  G  C  NaN   NaN   NaN      NaN        NaN
# 17    6  chr6:161785839:A:T  T  A  NaN   NaN   NaN      NaN        NaN
# 18    6  chr6:162443314:A:T  T  A  NaN   NaN   NaN      NaN        NaN
# 19    6  chr6:162443356:C:G  G  C  NaN   NaN   NaN      NaN        NaN
# 20   12  chr12:40310434:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 21   15  chr15:89319225:T:A  A  T  NaN   NaN   NaN      NaN        NaN
# 22   15  chr15:89321780:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 23   15  chr15:89321792:C:T  T  C  NaN   NaN   NaN  0.00000        0.0
# 24   15  chr15:89325610:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 25   15  chr15:89325679:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 26   15  chr15:89327166:C:T  T  C  NaN   NaN   NaN      NaN        NaN
# 27   15  chr15:89327201:C:T  T  C  NaN   NaN   NaN  0.00045        0.0
# 28   15  chr15:89329041:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 29   20   chr20:5100921:C:A  A  C  NaN   NaN   NaN      NaN        NaN
# 30   21  chr21:32726907:C:A  A  C  NaN   NaN   NaN      NaN        NaN
# 31   22  chr22:38115658:G:A  A  G  NaN   NaN   NaN      NaN        NaN
# 32   22  chr22:38132917:C:A  A  C  NaN   NaN   NaN      NaN        NaN
# 33   22  chr22:38169318:G:A  A  G  NaN   NaN   NaN      NaN        NaN
#
#     MAF_U_AAC  ...  MAF_U_EAS   MAF_EUR  MAF_A_EUR  MAF_U_EUR  MAF_FIN  \
# 0         NaN  ...        NaN  0.000348   0.000590   0.000109      NaN
# 1         NaN  ...        NaN       NaN        NaN        NaN      NaN
# 2         NaN  ...        NaN  0.000206   0.000283   0.000054      NaN
# 3         NaN  ...        NaN       NaN        NaN        NaN      NaN
# 4         NaN  ...        NaN  0.000000   0.000000   0.000000      NaN
# 5         NaN  ...        NaN  0.000064   0.000094   0.000000      NaN
# 6         NaN  ...        NaN       NaN        NaN        NaN      NaN
# 7         NaN  ...        NaN       NaN        NaN        NaN      NaN
# 8         NaN  ...        NaN       NaN        NaN        NaN      NaN
# 9         NaN  ...        NaN  0.000026   0.000047   0.000000      NaN
# 10        NaN  ...   0.000203  0.000000   0.000000   0.000000      NaN
# 11        NaN  ...        NaN  0.000000   0.000000   0.000000      NaN
# 12        NaN  ...   0.000407       NaN        NaN        NaN      NaN
# 13        NaN  ...        NaN  0.000270   0.000378   0.000163      NaN
# 14        NaN  ...   0.000407  0.000039   0.000024   0.000109      0.0
# 15        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 16        NaN  ...   0.000203       NaN        NaN        NaN      NaN
# 17        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 18        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 19        NaN  ...        NaN  0.000026   0.000047   0.000000      NaN
# 20        NaN  ...        NaN  0.000219   0.000330   0.000054      NaN
# 21        NaN  ...        NaN  0.000039   0.000047   0.000000      NaN
# 22        NaN  ...        NaN  0.000090   0.000094   0.000163      NaN
# 23   0.000000  ...        NaN  0.000283   0.000283   0.000217      NaN
# 24        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 25        NaN  ...        NaN  0.000026   0.000000   0.000054      NaN
# 26        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 27   0.000624  ...        NaN  0.000736   0.000804   0.000544      NaN
# 28        NaN  ...        NaN  0.000026   0.000047   0.000000      NaN
# 29        NaN  ...        NaN  0.000000   0.000000   0.000000      NaN
# 30        NaN  ...        NaN       NaN        NaN        NaN      NaN
# 31        NaN  ...        NaN  0.000026   0.000047   0.000000      NaN
# 32        NaN  ...   0.000203       NaN        NaN        NaN      NaN
# 33        NaN  ...        NaN       NaN        NaN        NaN      NaN
#
#     MAF_A_FIN  MAF_U_FIN   MAF_MDE  MAF_A_MDE  MAF_U_MDE
# 0         NaN        NaN       NaN        NaN        NaN
# 1         NaN        NaN       NaN        NaN        NaN
# 2         NaN        NaN       NaN        NaN        NaN
# 3         NaN        NaN       NaN        NaN        NaN
# 4         NaN        NaN       NaN        NaN        NaN
# 5         NaN        NaN       NaN        NaN        NaN
# 6         NaN        NaN  0.001721   0.003215        0.0
# 7         NaN        NaN       NaN        NaN        NaN
# 8         NaN        NaN       NaN        NaN        NaN
# 9         NaN        NaN       NaN        NaN        NaN
# 10        NaN        NaN       NaN        NaN        NaN
# 11        NaN        NaN       NaN        NaN        NaN
# 12        NaN        NaN       NaN        NaN        NaN
# 13        NaN        NaN  0.000861   0.001608        0.0
# 14        0.0        0.0       NaN        NaN        NaN
# 15        NaN        NaN       NaN        NaN        NaN
# 16        NaN        NaN       NaN        NaN        NaN
# 17        NaN        NaN       NaN        NaN        NaN
# 18        NaN        NaN       NaN        NaN        NaN
# 19        NaN        NaN       NaN        NaN        NaN
# 20        NaN        NaN  0.003448   0.006452        0.0
# 21        NaN        NaN       NaN        NaN        NaN
# 22        NaN        NaN       NaN        NaN        NaN
# 23        NaN        NaN       NaN        NaN        NaN
# 24        NaN        NaN       NaN        NaN        NaN
# 25        NaN        NaN       NaN        NaN        NaN
# 26        NaN        NaN       NaN        NaN        NaN
# 27        NaN        NaN       NaN        NaN        NaN
# 28        NaN        NaN       NaN        NaN        NaN
# 29        NaN        NaN       NaN        NaN        NaN
# 30        NaN        NaN       NaN        NaN        NaN
# 31        NaN        NaN       NaN        NaN        NaN
# 32        NaN        NaN       NaN        NaN        NaN
# 33        NaN        NaN       NaN        NaN        NaN
#
# [34 rows x 37 columns]

# %%
# get number of pathogenic variants within each PD gene of interest in each ancestry

gene_path_vars = annotated_pathogenic_vars[['Gene.refGene','avsnp151','snpID']].copy()
gene_path_vars = gene_path_vars.merge(all_anc_freqs, left_on=['snpID'], right_on=['SNP'], how='outer')
gene_path_vars = gene_path_vars.rename(columns={'Gene.refGene':'GENE', 'MAF':'MAF_SAS', 'MAF_A':'MAF_A_SAS', 'MAF_U':'MAF_U_SAS'})

gene_path_vars.fillna('NA').to_csv(f'{workspace}/all_anc_freqs.txt', sep='\t', header=True, index=False)

drop_cols = ['avsnp151','CHR','SNP','A1','A2'] + [f'MAF_A_{anc}' for anc in ancestries] + [f'MAF_U_{anc}' for anc in ancestries]
per_gene_path_vars = gene_path_vars.drop(drop_cols, axis=1)
col_order = ['GENE','snpID'] + [f'MAF_{anc}' for anc in ancestries]
per_gene_path_vars = per_gene_path_vars[col_order]

per_gene_counts = per_gene_path_vars.groupby('GENE').count().reset_index()
per_gene_counts
# Out:
#       GENE  snpID  MAF_AAC  MAF_AFR  MAF_AJ  MAF_AMR  MAF_CAH  MAF_CAS  \
# 0  ATP13A2      5        0        1       0        1        0        0
# 1      GBA      7        0        2       0        0        1        0
# 2    LRRK2      1        0        0       0        0        0        1
# 3    PINK1      3        0        0       0        0        0        0
# 4   PLA2G6      3        0        0       0        1        0        1
# 5     POLG      8        2        4       1        0        0        0
# 6     PRKN      5        0        0       1        1        1        0
# 7    SYNJ1      1        0        1       0        0        0        0
# 8  TMEM230      1        0        0       0        0        0        0
#
#    MAF_EAS  MAF_EUR  MAF_FIN  MAF_MDE  MAF_SAS
# 0        1        3        0        0        0
# 1        0        4        0        1        0
# 2        0        1        0        1        0
# 3        2        2        1        1        0
# 4        1        1        0        0        0
# 5        0        6        0        0        0
# 6        1        1        0        0        0
# 7        0        0        0        0        0
# 8        0        1        0        0        0

# %%
# blauwendraat PD gene classifications

gene_classifications = {'SNCA':'very high',\
                        'PRKN':'very high',\
                        'UCHL1':'low',\
                        'PARK7':'very high',\
                        'LRRK2':'very high',\
                        'PINK1':'very high',\
                        'POLG':'high',\
                        'HTRA2':'low',\
                        'ATP13A2':'very high',\
                        'FBXO7':'very high',\
                        'GIGYF2':'low',\
                        'GBA':'very high',\
                        'PLA2G6':'very high',\
                        'EIF4G1':'low',\
                        'VPS35':'very high',\
                        'DNAJC6':'high',\
                        'SYNJ1':'high',\
                        'DNAJC13':'low',\
                        'TMEM230':'low',\
                        'VPS13C':'high',\
                        'LRP10':'low'}

gene_classifications = pd.DataFrame.from_dict(gene_classifications, orient='index').reset_index().rename(columns={'index':'GENE',0:'class'})

# %%
# count how many pathogenic variants per gene are present in each ancestry

col_order = ['GENE','class','snpID'] + [f'MAF_{anc}' for anc in ancestries]
per_gene_class_counts = per_gene_counts.merge(gene_classifications, on='GENE', how='outer')[col_order]

class_ord = {'low':2,'high':1,'very high':0}
per_gene_class_counts.sort_values(by='class', key=lambda x: x.map(class_ord)).fillna(0).to_csv(f'{workspace}/per_gene_per_anc_pathogenic_var_counts.txt', sep='\t', index=False)

# %%
# compare pathogenic variants with gnomAD annotations
# - annotations were pulled manually for each gene of interest from gnomAD site and then combined to one file

gnomad_info = pd.read_csv(f'{workspace}/gnomAD_selectedgenes_pathogenic_vars.txt', sep='\t')
gnomad_info
# Out:
#         gene          gnomAD_ID  Chromosome  Position         rsIDs Reference  \
# 0    ATP13A2   1-16986881-CAG-C           1  16986881  rs1570759415       CAG
# 1    ATP13A2  1-16986885-GAGA-G           1  16986885  rs1057519290      GAGA
# 2    ATP13A2    1-16986886-A-AG           1  16986886   rs747617559         A
# 3    ATP13A2     1-16988455-C-T           1  16988455   rs144701072         C
# 4    ATP13A2     1-16989739-A-C           1  16989739   rs587777053         A
# ..       ...                ...         ...       ...           ...       ...
# 235  TMEM230     20-5100921-C-A          20   5100921   rs764786986         C
# 236    UCHL1     4-41256996-A-C           4  41256996   rs397515634         A
# 237    UCHL1  4-41257706-C-CGCT           4  41257706   rs749368841         C
# 238    UCHL1   4-41261751-CAG-C           4  41261751  rs1310363710       CAG
# 239    UCHL1     4-41264108-C-T           4  41264108  rs2154087267         C
#
#     Alternate ClinVar_ClnSignificance  ClinVar_varID  allele_count  \
# 0           C              Pathogenic       660925.0             1
# 1           G              Pathogenic       374887.0             1
# 2          AG              Pathogenic      1968613.0             2
# 3           T              Pathogenic        66099.0            15
# 4           C              Pathogenic        66098.0             1
# ..        ...                     ...            ...           ...
# 235         A              Pathogenic       243014.0             5
# 236         C              Pathogenic        88635.0             2
# 237      CGCT              Pathogenic      2077519.0             3
# 238         C              Pathogenic      3068443.0             1
# 239         T              Pathogenic      1380167.0             1
#
#      allele_number   allele_freq
# 0          1614048  6.195603e-07
# 1          1614104  6.195388e-07
# 2          1614040  1.239127e-06
# 3          1613774  9.294982e-06
# 4          1614078  6.195487e-07
# ..             ...           ...
# 235        1613958  3.097974e-06
# 236        1614182  1.239018e-06
# 237        1580822  1.897747e-06
# 238        1613326  6.198375e-07
# 239        1614208  6.194989e-07
#
# [240 rows x 12 columns]

# %%
annotated_path_vars = pd.read_csv(f'{workspace}/annotated_pathogenic_vars.txt', sep='\t')

gnomad_info['in_gp2'] = gnomad_info['rsIDs'].isin(annotated_path_vars['avsnp151'].tolist())
gnomad_info.to_csv(f'{workspace}/gnomAD_inGP2.txt', sep='\t', header=True, index=False)
